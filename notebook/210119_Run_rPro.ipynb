# %% [markdown]
# # Run: rdrp1 Prokarya / Non-Eukarya
#
# ```
# Lead     : ababaian
# Issue    :
# Version  : v0.4.0-dev : diamond-dev branch
# start    : 2021 01 18
# complete : 2021 01 xx
# files    : ~/serratus/notebook/210108_ab/
# s3_files : s3://serratus-public/notebook/210108_ab/
# output   : s3://serratus-public/out/210118_rQC/
# ```
#
# ### Intro/Objectives
#
# > Old glasses clinking and a new order's blinking, And I, I should be floating but I'm weighted by thinking
#
# ### Prokaya / Other
#
# - File: `pro_SraRunInfo.csv`
#
# Search Term:
# ```
# ("type_rnaseq"[Filter] OR "metagenomic"[Filter] OR "metatranscriptomic"[Filter]) NOT "Eukaryota"[Organism] AND cluster_public[prop] AND "platform illumina"[Properties]
# ```
#
# SRA Accessed: `2020/12/31`
#
# Results: `2 126 560 / 2 672 802 (with redundancy)`
#
# [See: 201230_sraRunInfo_Update.ipynb](./201230_sraRunInfo_Update.ipynb)

# %%
# ON EC2
# Make QC SRA list
mkdir -p sra; cd sra
mkdir -p pro

aws s3 cp s3://serratus-public/tmp/completed.sra ./
aws s3 sync s3://serratus-public/notebook/201230_sra/pro_SraRunInfo.csv ./

remove_done () {
  COMPLETE=$1
  SRA=$2
  
  # Sort unique SRA in the input RunInfo file
  cut -f1 -d',' $SRA \
    | sort -u \
    > inputsra.tmp
  
  # Ensure completed SRA list is sorted
  sort $COMPLETE > complete.sort.tmp
  
  # Supress SRA-accessions only in file 1 or file 1+2
  # Show SRA unique to file 2
  # parse into a regex expression to find matching lines
  comm -1 -3 complete.sort.tmp inputsra.tmp \
    | sed 's/^$\n//g' - \
    | sed 's/^/^/g' - \
    | sed 's/$/,/g' \
    > incomplete.in.$SRA
  
  split -l 10000 incomplete.in.$SRA inc.split.
  
  rm -f undone_$SRA
  for INC in $(ls inc.split.*); do
    grep -f $INC $SRA >> undone_$SRA
  done
  
  
  #grep -f incomplete.in.$SRA $SRA > undone_$SRA
  
  #rm *.tmp
  # Still crashing due to high memory
  # but will give a list of "undone" accessions
}

remove_done completed.sra pro_SraRunInfo.csv

split -l 275000 undone_pro_SraRunInfo.csv pro2_SraRunInfo.csv.

# Manually fix header column (remove duplicates)
aws s3 sync pro2_SraRunInfo.csv. s3://serratus-public/notebook/201230_sra/pro2/

# %%
## Fire up EC2 Instance
#sudo yum install -y docker
#sudo yum install -y git
#sudo service docker start

## Download latest serratus repo
#git clone -b diamond-dev https://github.com/ababaian/serratus.git; cd serratus/containers

## If you want to upload containers to your repository, include this.
#export DOCKERHUB_USER='serratusbio' # optional
#sudo docker login # optional
#
## Build all containers and upload them docker hub repo (if available)
#./build_containers.sh

# %% [markdown]
# ### Initialize local workspace

# %%
# Serratus commit version
SERRATUS="/home/artem/serratus"
cd $SERRATUS

# Create local run directory
WORK="$SERRATUS/notebook/210111_ab"
mkdir -p $WORK; cd $WORK

# S3 notebook path
S3_WORK='s3://serratus-public/notebook/210111_ab'

# date and version
date
git rev-parse HEAD # commit version
# Out:
# Tue Jan 19 15:19:10 PST 2021
# 2ddf24166fdded0bc89a96b2541bcbc7442f98f9

# %%
cd $WORK

# Copy SRA Run Info
aws s3 sync s3://serratus-public/notebook/201230_sra/pro2/ ./

md5sum pro2*
ls -alh pro2*
# Out:
# download: s3://serratus-public/notebook/201230_sra/pro2/pro2_SraRunInfo.csv.aa to ./pro2_SraRunInfo.csv.aa
# download: s3://serratus-public/notebook/201230_sra/pro2/pro2_SraRunInfo.csv.ab to ./pro2_SraRunInfo.csv.ab
# download: s3://serratus-public/notebook/201230_sra/pro2/pro2_SraRunInfo.csv.ac to ./pro2_SraRunInfo.csv.ac
# download: s3://serratus-public/notebook/201230_sra/pro2/pro2_SraRunInfo.csv.ae to ./pro2_SraRunInfo.csv.ae
# download: s3://serratus-public/notebook/201230_sra/pro2/pro2_SraRunInfo.csv.ad to ./pro2_SraRunInfo.csv.ad
# download: s3://serratus-public/notebook/201230_sra/pro2/pro2_SraRunInfo.csv.af to ./pro2_SraRunInfo.csv.af
# af69bc553fc3c60bc77f18216dc549fb  pro2_SraRunInfo.csv.aa
# ba41cfb461e02214537550a95c88514c  pro2_SraRunInfo.csv.ab
# 76b3466998a5d043060e00d5f84c8801  pro2_SraRunInfo.csv.ac
# 718ded12e398b38d925b70729d4df5a0  pro2_SraRunInfo.csv.ad
# cb56abdccddcfc52e951bc75b7f34404  pro2_SraRunInfo.csv.ae
# ...

# %%
# Prokaryote search query updated on Jan 20th.
# These are the SRA that are exclusive to the completed runs
# from BATCH 1 to BATCH 6
cd $WORK
aws s3 cp s3://serratus-public/tmp/pro_q1_SraRunInfo.csv ./
aws s3 cp s3://serratus-public/tmp/pro_q2_SraRunInfo.csv ./
# Out:
# client_loop: send disconnect: Broken pipe
# download: s3://serratus-public/tmp/pro_q1_SraRunInfo.csv to ./pro_q1_SraRunInfo.csv
# download: s3://serratus-public/tmp/pro_q2_SraRunInfo.csv to ./pro_q2_SraRunInfo.csv

# %%
#aws s3 sync ./ $S3_WORK/

# %% [markdown]
# ### Terraform Initialize

# %%
## UPDATE serratus/terraform/main/main.tf
# main/main.tf LINE 187 = "-b s3://serratus-public/out/yymmdd_id"

# %%
# For rapid batching; copy out serratus folder
# PROTEIN / DNA MUST BE SET IN CONFIG FILE
# main/main.tf LINE 166
#   options            = "-k ${module.work_bucket.name} -a bowtie2"
#   options            = "-k ${module.work_bucket.name} -a diamond"
# Set output location
# main/main.tf LINE 187 = "-b s3://serratus-public/out/yymmdd_id"

TF=$SERRATUS/terraform/main
cd $TF
git diff main.tf
terraform init

# Launch Terraform Cluster
# Initialize the serratus cluster with minimal nodes
terraform apply -auto-approve
# Out:
# Connection to ec2-18-210-227-245.compute-1.amazonaws.com closed by remote host.
# diff --git a/terraform/main/main.tf b/terraform/main/main.tf
# index de2d00d..363180e 100644
# --- a/terraform/main/main.tf
# +++ b/terraform/main/main.tf
# @@ -12,14 +12,14 @@ variable "aws_region" {
#  }
#
#  variable "dl_size" {
# -  type    = number
# -  default = 0
# +  type        = number
# +  default     = 0
#    description = "Default number of downloader nodes (ASG)"
#  }
#
#  variable "align_size" {
# -  type    = number
# -  default = 0
# +  type        = number
# +  default     = 0
#    description = "Default number of aligner nodes (ASG)"
#  }
#
# @@ -38,14 +38,22 @@ variable "dockerhub_account" {
#  }
#
#  variable "scheduler_port" {
# -  type  = number
# +  type    = number
#    default = 8000
#  }
#
# +variable "output_bucket" {
# +  type = string
# +}
# +
# +//variable "metrics_ip" {
# +//  type = string
# +//}
# +
#  // PROVIDER/AWS ##############################
#  provider "aws" {
# ...

# %% [markdown]
# Serratus Config backup
# ```
# {
#   "ALIGN_ARGS": "--very-sensitive-local",
#   "ALIGN_MAX_INCREASE": 40,
#   "ALIGN_SCALING_CONSTANT": 0.08,
#   "ALIGN_SCALING_ENABLE": true,
#   "ALIGN_SCALING_MAX": 3200,
#   "CLEAR_INTERVAL": 999999,
#   "DL_ARGS": "",
#   "DL_MAX_INCREASE": 20,
#   "DL_SCALING_CONSTANT": 0.1,
#   "DL_SCALING_ENABLE": true,
#   "DL_SCALING_MAX": 1350,
#   "GENOME": "rdrp1",
#   "MERGE_ARGS": "protein",
#   "MERGE_MAX_INCREASE": 25,
#   "MERGE_SCALING_CONSTANT": 0.1,
#   "MERGE_SCALING_ENABLE": true,
#   "MERGE_SCALING_MAX": 25,
#   "SCALING_INTERVAL": 120,
#   "VIRTUAL_SCALING_INTERVAL": 35
# }
# ```

# %%
cd $TF

# Open SSH tunnels to the monitor
./create_tunnels.sh

# If you get an error on port
# run:
# ps aux | grep ssh
# sudo kill <PID of SSH>
# Out:
# ...
# Tunnels created:
#     localhost:3000 = grafana
#     localhost:9090 = prometheus
#     localhost:5432 = postgres
#     localhost:8000 = scheduler

# %%
#BATCH 1
cd $WORK
BATCH1='pro2_SraRunInfo.csv.aa'
wc -l $WORK/$BATCH1
# Out:
# 275001 /home/artem/serratus/notebook/210111_ab/pro2_SraRunInfo.csv.aa

# %%
# Upload SraRunInfo.csv into Serratus
cd $TF
./uploadSRA.sh $WORK/$BATCH1
# Out:
# Loading SRARunInfo into scheduler
#   File: /home/artem/serratus/notebook/210111_ab/pro2_SraRunInfo.csv.aa
#   date: Tue Jan 19 16:00:01 PST 2021
#   wc  : 275001 /home/artem/serratus/notebook/210111_ab/pro2_SraRunInfo.csv.aa
#   md5 : af69bc553fc3c60bc77f18216dc549fb  /home/artem/serratus/notebook/210111_ab/pro2_SraRunInfo.csv.aa
#
#
# --------------------------
# tmp.chunk00
# 10001 tmp.chunk00_sraRunInfo.csv
# 6d6390c185a70da185cc6cc2cf088d09  tmp.chunk00_sraRunInfo.csv
# {"inserted_rows":10000,"total_rows":10000}
# --------------------------
# tmp.chunk01
# 10001 tmp.chunk01_sraRunInfo.csv
# 501102f9d746296ff58ecd849bf042c8  tmp.chunk01_sraRunInfo.csv
# {"inserted_rows":10000,"total_rows":20000}
# --------------------------
# tmp.chunk02
# 10001 tmp.chunk02_sraRunInfo.csv
# 3985f8686ef6cfd1a49c25cd20f546f5  tmp.chunk02_sraRunInfo.csv
# {"inserted_rows":10000,"total_rows":30000}
# --------------------------
# tmp.chunk03
# 10001 tmp.chunk03_sraRunInfo.csv
# ...

# %%
# BATCH 2
cd $WORK
BATCH2='pro2_SraRunInfo.csv.ab'
wc -l $WORK/$BATCH2
# Out:
# 275001 /home/artem/serratus/notebook/210111_ab/pro2_SraRunInfo.csv.ab

# %%
# Upload SraRunInfo.csv into Serratus
cd $TF
./uploadSRA.sh $WORK/$BATCH2
# Out:
# Loading SRARunInfo into scheduler
#   File: /home/artem/serratus/notebook/210111_ab/pro2_SraRunInfo.csv.ab
#   date: Tue Jan 19 19:27:09 PST 2021
#   wc  : 275001 /home/artem/serratus/notebook/210111_ab/pro2_SraRunInfo.csv.ab
#   md5 : ba41cfb461e02214537550a95c88514c  /home/artem/serratus/notebook/210111_ab/pro2_SraRunInfo.csv.ab
#
#
# --------------------------
# tmp.chunk00
# 10001 tmp.chunk00_sraRunInfo.csv
# 748e6ae74bd1c31740c0e7c48fad9bd7  tmp.chunk00_sraRunInfo.csv
# {"inserted_rows":10000,"total_rows":10000}
# --------------------------
# tmp.chunk01
# 10001 tmp.chunk01_sraRunInfo.csv
# 076211a56fced378e2db3197407fb8ec  tmp.chunk01_sraRunInfo.csv
# {"inserted_rows":10000,"total_rows":20000}
# --------------------------
# tmp.chunk02
# 10001 tmp.chunk02_sraRunInfo.csv
# 4e04743fc88efff5ae7ab0f5b6ab7818  tmp.chunk02_sraRunInfo.csv
# {"inserted_rows":10000,"total_rows":30000}
# --------------------------
# tmp.chunk03
# 10001 tmp.chunk03_sraRunInfo.csv
# ...

# %%
# BATCH 3
cd $WORK
BATCH3='pro2_SraRunInfo.csv.ac'
wc -l $WORK/$BATCH3
# Out:
# 275001 /home/artem/serratus/notebook/210111_ab/pro2_SraRunInfo.csv.ac

# %%
# Upload SraRunInfo.csv into Serratus
cd $TF
./uploadSRA.sh $WORK/$BATCH3
# Out:
# Loading SRARunInfo into scheduler
#   File: /home/artem/serratus/notebook/210111_ab/pro2_SraRunInfo.csv.ac
#   date: Tue Jan 19 22:10:36 PST 2021
#   wc  : 275001 /home/artem/serratus/notebook/210111_ab/pro2_SraRunInfo.csv.ac
#   md5 : 76b3466998a5d043060e00d5f84c8801  /home/artem/serratus/notebook/210111_ab/pro2_SraRunInfo.csv.ac
#
#
# --------------------------
# tmp.chunk00
# 10001 tmp.chunk00_sraRunInfo.csv
# 0a5788ed7e5b442ee42dcb223e052062  tmp.chunk00_sraRunInfo.csv
# {"inserted_rows":10000,"total_rows":10000}
# --------------------------
# tmp.chunk01
# 10001 tmp.chunk01_sraRunInfo.csv
# 240c3c636e3b9f1ccc71d9e2326c8f20  tmp.chunk01_sraRunInfo.csv
# {"inserted_rows":10000,"total_rows":20000}
# --------------------------
# tmp.chunk02
# 10001 tmp.chunk02_sraRunInfo.csv
# 05b51cd080f18018d313f5a4f39f73a5  tmp.chunk02_sraRunInfo.csv
# {"inserted_rows":10000,"total_rows":30000}
# --------------------------
# tmp.chunk03
# 10001 tmp.chunk03_sraRunInfo.csv
# ...

# %%
# BATCH 4
cd $WORK
BATCH4='pro2_SraRunInfo.csv.ad'
wc -l $WORK/$BATCH4
# Out:
# 275001 /home/artem/serratus/notebook/210111_ab/pro2_SraRunInfo.csv.ad

# %%
# Upload SraRunInfo.csv into Serratus
cd $TF
./uploadSRA.sh $WORK/$BATCH4
# Out:
# Loading SRARunInfo into scheduler
#   File: /home/artem/serratus/notebook/210111_ab/pro2_SraRunInfo.csv.ad
#   date: Wed Jan 20 07:17:29 PST 2021
#   wc  : 275001 /home/artem/serratus/notebook/210111_ab/pro2_SraRunInfo.csv.ad
#   md5 : 718ded12e398b38d925b70729d4df5a0  /home/artem/serratus/notebook/210111_ab/pro2_SraRunInfo.csv.ad
#
#
# --------------------------
# tmp.chunk00
# 10001 tmp.chunk00_sraRunInfo.csv
# 27a5adcce99d0e4cc2ea7d1848af1d60  tmp.chunk00_sraRunInfo.csv
# {"inserted_rows":10000,"total_rows":10000}
# --------------------------
# tmp.chunk01
# 10001 tmp.chunk01_sraRunInfo.csv
# 432139b05edc13102dc170fb908c9a32  tmp.chunk01_sraRunInfo.csv
# {"inserted_rows":10000,"total_rows":20000}
# --------------------------
# tmp.chunk02
# 10001 tmp.chunk02_sraRunInfo.csv
# 530b47e35689d6a933ee5ad52b3ab010  tmp.chunk02_sraRunInfo.csv
# {"inserted_rows":10000,"total_rows":30000}
# --------------------------
# tmp.chunk03
# 10001 tmp.chunk03_sraRunInfo.csv
# ...

# %%
# BATCH 5
cd $WORK
BATCH5='pro2_SraRunInfo.csv.ae'
wc -l $WORK/$BATCH5
# Out:
# 275001 /home/artem/serratus/notebook/210111_ab/pro2_SraRunInfo.csv.ae

# %%
# Upload SraRunInfo.csv into Serratus
cd $TF
./uploadSRA.sh $WORK/$BATCH5
# Out:
# Loading SRARunInfo into scheduler
#   File: /home/artem/serratus/notebook/210111_ab/pro2_SraRunInfo.csv.ae
#   date: Wed Jan 20 10:07:56 PST 2021
#   wc  : 275001 /home/artem/serratus/notebook/210111_ab/pro2_SraRunInfo.csv.ae
#   md5 : cb56abdccddcfc52e951bc75b7f34404  /home/artem/serratus/notebook/210111_ab/pro2_SraRunInfo.csv.ae
#
#
# --------------------------
# tmp.chunk00
# 10001 tmp.chunk00_sraRunInfo.csv
# 115e9e01af592c3e154d338749d7346f  tmp.chunk00_sraRunInfo.csv
# {"inserted_rows":10000,"total_rows":10000}
# --------------------------
# tmp.chunk01
# 10001 tmp.chunk01_sraRunInfo.csv
# fe852570bdba18128a7b23ff0f9fe7ce  tmp.chunk01_sraRunInfo.csv
# {"inserted_rows":10000,"total_rows":20000}
# --------------------------
# tmp.chunk02
# 10001 tmp.chunk02_sraRunInfo.csv
# fe9d378f147b5622ea242842a4a7702b  tmp.chunk02_sraRunInfo.csv
# {"inserted_rows":10000,"total_rows":30000}
# --------------------------
# tmp.chunk03
# 10001 tmp.chunk03_sraRunInfo.csv
# ...

# %%
# BATCH 6
cd $WORK
BATCH6='pro2_SraRunInfo.csv.af'
wc -l $WORK/$BATCH6
# Out:
# 170848 /home/artem/serratus/notebook/210111_ab/pro2_SraRunInfo.csv.af

# %%
# Upload SraRunInfo.csv into Serratus
cd $TF
./uploadSRA.sh $WORK/$BATCH6
# Out:
# Loading SRARunInfo into scheduler
#   File: /home/artem/serratus/notebook/210111_ab/pro2_SraRunInfo.csv.af
#   date: Wed Jan 20 13:22:58 PST 2021
#   wc  : 170848 /home/artem/serratus/notebook/210111_ab/pro2_SraRunInfo.csv.af
#   md5 : 0618b460abad11583ef7263e52ed1f40  /home/artem/serratus/notebook/210111_ab/pro2_SraRunInfo.csv.af
#
#
# --------------------------
# tmp.chunk00
# 10001 tmp.chunk00_sraRunInfo.csv
# 780ebc02d0f45691bfad7e87543facd1  tmp.chunk00_sraRunInfo.csv
# {"inserted_rows":10000,"total_rows":10000}
# --------------------------
# tmp.chunk01
# 10001 tmp.chunk01_sraRunInfo.csv
# fd61fecc9778845757f1e16b87183017  tmp.chunk01_sraRunInfo.csv
# {"inserted_rows":10000,"total_rows":20000}
# --------------------------
# tmp.chunk02
# 10001 tmp.chunk02_sraRunInfo.csv
# 02f8ba47698f0f42310caa4948ff2022  tmp.chunk02_sraRunInfo.csv
# {"inserted_rows":10000,"total_rows":30000}
# --------------------------
# tmp.chunk03
# 10001 tmp.chunk03_sraRunInfo.csv
# ...

# %%
# BATCH 7 -- QC 1
cd $WORK
BATCH7='pro_q1_SraRunInfo.csv'
wc -l $WORK/$BATCH7
# Out:
# 295001 /home/artem/serratus/notebook/210111_ab/pro_q1_SraRunInfo.csv

# %%
# Upload SraRunInfo.csv into Serratus
cd $TF
./uploadSRA.sh $WORK/$BATCH7
# Out:
# Loading SRARunInfo into scheduler
#   File: /home/artem/serratus/notebook/210111_ab/pro_q1_SraRunInfo.csv
#   date: Wed Jan 20 17:03:16 PST 2021
#   wc  : 295001 /home/artem/serratus/notebook/210111_ab/pro_q1_SraRunInfo.csv
#   md5 : 407fa64c3b572e6fe07266669e65304a  /home/artem/serratus/notebook/210111_ab/pro_q1_SraRunInfo.csv
#
#
# --------------------------
# tmp.chunk00
# 10001 tmp.chunk00_sraRunInfo.csv
# 2552e35ebc18da31f5b5b79089d1d1e8  tmp.chunk00_sraRunInfo.csv
# {"inserted_rows":10000,"total_rows":10000}
# --------------------------
# tmp.chunk01
# 10001 tmp.chunk01_sraRunInfo.csv
# f15d97c5ef3493672672e8bf4d92efbb  tmp.chunk01_sraRunInfo.csv
# {"inserted_rows":10000,"total_rows":20000}
# --------------------------
# tmp.chunk02
# 10001 tmp.chunk02_sraRunInfo.csv
# 24b51b5c3b7673a1c51bb638bd677e2d  tmp.chunk02_sraRunInfo.csv
# {"inserted_rows":10000,"total_rows":30000}
# --------------------------
# tmp.chunk03
# 10001 tmp.chunk03_sraRunInfo.csv
# ...

# %%
# BATCH 8 -- QC 2
cd $WORK
BATCH8='pro_q2_SraRunInfo.csv'
wc -l $WORK/$BATCH8
# Out:
# 296017 /home/artem/serratus/notebook/210111_ab/pro_q2_SraRunInfo.csv

# %%
# Upload SraRunInfo.csv into Serratus
cd $TF
./uploadSRA.sh $WORK/$BATCH8
# Out:
# Loading SRARunInfo into scheduler
#   File: /home/artem/serratus/notebook/210111_ab/pro_q2_SraRunInfo.csv
#   date: Wed Jan 20 20:56:06 PST 2021
#   wc  : 296017 /home/artem/serratus/notebook/210111_ab/pro_q2_SraRunInfo.csv
#   md5 : 20dd8eeec7bf0b260bc0e670b8956442  /home/artem/serratus/notebook/210111_ab/pro_q2_SraRunInfo.csv
#
#
# --------------------------
# tmp.chunk00
# 10001 tmp.chunk00_sraRunInfo.csv
# 52b1c64e4fdfb523e0df9894a90cfb20  tmp.chunk00_sraRunInfo.csv
# {"inserted_rows":10000,"total_rows":10000}
# --------------------------
# tmp.chunk01
# 10001 tmp.chunk01_sraRunInfo.csv
# 552e54c34633acd7de6c630cd7a6d4a9  tmp.chunk01_sraRunInfo.csv
# {"inserted_rows":10000,"total_rows":20000}
# --------------------------
# tmp.chunk02
# 10001 tmp.chunk02_sraRunInfo.csv
# 8ba21e4222d942e99ae7afeec3fbf2b5  tmp.chunk02_sraRunInfo.csv
# {"inserted_rows":10000,"total_rows":30000}
# --------------------------
# tmp.chunk03
# 10001 tmp.chunk03_sraRunInfo.csv
# ...

# %% [markdown]
# ## Run Serratus

# %%
# Set Cluster Parameters =============================
## get Config File (if it doesn't exist)
# curl localhost:8000/config | jq > serratus-config.json

cd $TF
# Make local changes to config file
echo "  Cluster Config File: "
cat serratus-config.json
echo ""
echo ""
# Re-upload config file
curl -sT serratus-config.json localhost:8000/config
# Out:
#   Cluster Config File:
# {
#   "ALIGN_ARGS": "--very-sensitive-local",
#   "ALIGN_MAX_INCREASE": 35,
#   "ALIGN_SCALING_CONSTANT": 0.1,
#   "ALIGN_SCALING_ENABLE": true,
#   "ALIGN_SCALING_MAX": 20,
#   "CLEAR_INTERVAL": 999999,
#   "DL_ARGS": "",
#   "DL_MAX_INCREASE": 20,
#   "DL_SCALING_CONSTANT": 0.1,
#   "DL_SCALING_ENABLE": true,
#   "DL_SCALING_MAX": 0,
#   "GENOME": "rdrp1",
#   "MERGE_ARGS": "protein",
#   "MERGE_MAX_INCREASE": 100,
#   "MERGE_SCALING_CONSTANT": 0.1,
#   "MERGE_SCALING_ENABLE": true,
#   "MERGE_SCALING_MAX": 35,
#   "SCALING_INTERVAL": 120,
#   "VIRTUAL_SCALING_INTERVAL": 35
# }
#
# ...

# %% [markdown]
# ### Error handling

# %%
## Stop postgres if it's running 
# systemctl stop postgresql

## Connect to postgres
# psql -h localhost postgres postgres

#  psql -h localhost postgres postgres -c "DELETE FROM blocks WHERE state = 'done';"

### ACCESSION OPERATIONS
## Reset SPLITTING accessions to NEW
# UPDATE acc SET state = 'new' WHERE state = 'splitting';

## Reset SPLIT_ERR accessions to NEW
## (repeated failures can be missing SRA data)
# UPDATE acc SET state = 'new' WHERE state = 'split_err';

## Reset MERGE_ERR accessions to SPLIT_DONE
# UPDATE acc SET state = 'split_done' WHERE state = 'merge_err';

## Clear DONE Accessions (ONLY ON COMPLETION)
# DELETE FROM acc WHERE state = 'merge_done';

### BLOCK OPERATIONS

##  Reset FAIL blocks to NEW
# UPDATE blocks SET state = 'new' WHERE state = 'fail';

# Reset ALIGNING blocks to NEW
# UPDATE blocks SET state = 'new' WHERE state = 'aligning';

# Clear Done
# DELETE FROM blocks WHERE state = 'done';

# RESET STATE
# DELETE FROM blocks WHERE state = 'done';
# DELETE FROM blocks WHERE state = 'fail';
#
#
# DELETE FROM acc WHERE state = 'split_err';
# DELETE FROM acc WHERE state = 'merging';
# DELETE FROM acc WHERE state = 'merge_err';
# DELETE FROM acc WHERE state = 'split_done';

# %%
# Regular Shutdown
cd $TF
terraform destroy

## Nuke Shutdown
#cd $TF
#
#aws ec2 describe-instances \
#  --filter Name=tag:Name,Values=serratus-align-instance \
#  > align_instances.json
#
#jq '.Reservations[].Instances[].InstanceId' -r align_instances.json \
#  | pv -l \
#  | xargs -n10 -P10 aws ec2 terminate-instances --instance-ids

# %% [markdown]
# # Notes:

# %% [markdown]
# psummary: `https://serratus-public.s3.amazonaws.com/out/210108_r1p/psummary/<SRA>.psummary`
#
# SRA site: `https://www.ncbi.nlm.nih.gov/sra/?term=<SRA>`

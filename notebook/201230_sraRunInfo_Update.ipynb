# %% [markdown]
# # SRA Run Info Update
# ```
# Lead     : ababaian
# Issue    : <github issue #>
# start    : 2020 12 30
# complete : 2021 01 02
# files    : ~/serratus/notebook/201230_sra/
# s3 files : s3://serratus-public/notebook/201230_sra/
# ```
#
# ## Introduction
#
# It has been about half a year since the last big batches of SRA Runs. This will be an update of the main "SRA" files for more runs in the future. (Exponential growth and all!).

# %% [markdown]
# ### Initialization

# %%
# Serratus commit version
SERRATUS="/home/artem/serratus"
cd $SERRATUS

# Create local run directory
WORK="$SERRATUS/notebook/201230_sra"
mkdir -p $WORK; cd $WORK

# S3 notebook path
S3_WORK='s3://serratus-public/notebook/201230_sra'

# date and version
date
git rev-parse HEAD # commit version
# Out:
# Wed Dec 30 09:01:24 PST 2020
# 05de2c7adfd6951e98261ff5701e9303aed15cbc

# %% [markdown]
# ### Updates
#
# (See previous RunInfo files below)
#
# Files downloaded on wired Raspberry Pi connection at home.

# %% [markdown]
# ### Total Unique: ` 4 449 528`
#
# ### Human (non-controlled data)
#
# - File: `hu_SraRunInfo.csv`
#
# Search Term:
# ```
# "Homo sapiens"[Organism] AND ("type_rnaseq"[Filter]) AND cluster_public[prop] AND "platform illumina"[Properties]
# ```
# SRA Accessed: `2020/12/30`
#
# Results: `789 931`
#
# **AND**
#
# - File: `hu_meta_SraRunInfo.csv`
#
# Search Term:
# ```
# "Homo sapiens"[Organism] AND ("metagenomic"[Filter] OR "metatranscriptomic"[Filter]) AND cluster_public[prop] AND "platform illumina"[Properties]
# ```
# SRA Accessed: `2020/12/30`
#
# Results: `47 763`
#
# ### Mouse
#
# - File: `mu_SraRunInfo.csv`
#
# Search Term:
# ```
# "Mus musculus"[orgn] AND ("type_rnaseq"[Filter] OR "metagenomic"[Filter] OR "metatranscriptomic"[Filter]) AND "platform illumina"[Properties]
# ```
#
# SRA Accessed: `2020/12/30`
#
# Results: `1 058 559`
#
# ### Mammalian
#
# - File: `mamm_SraRunInfo.csv`
#
# Search Term:
# ```
# ("Mammalia"[Organism] NOT "Homo sapiens"[Organism] NOT "Mus musculus"[orgn]) AND ("type_rnaseq"[Filter] OR "metagenomic"[Filter] OR "metatranscriptomic"[Filter]) AND "platform illumina"[Properties]
# ```
# SRA Accessed: `2020/12/30`
#
# Results: `126 382`
#
# ### Vertebrate
#
# - File: `vert_SraRunInfo.csv`
#
# Search Term:
# ```
# ("Vertebrata"[Organism] NOT "Mammalia"[Organism] NOT "Homo sapiens"[Organism] NOT "Mus musculus"[orgn]) AND ("type_rnaseq"[Filter] OR "metagenomic"[Filter] OR "metatranscriptomic"[Filter]) AND cluster_public[prop] AND "platform illumina"[Properties]
# ```
# SRA Accessed: `2020/12/30`
#
# Results: `114 078`
#
# ### Invertebrate
# previous (NOT VERTEBRATE: `2092939##` # INCOMPLETE --> BREAK UP EUKARYA / PROKARYA
#
# - File: `inv_SraRunInfo.csv`
#
# Search Term:
# ```
# ("Metazoa"[Organism] NOT "Vertebrata"[Organism]) ("type_rnaseq"[Filter] OR "metagenomic"[Filter] OR "metatranscriptomic"[Filter]) AND cluster_public[prop] AND "platform illumina"[Properties]
# ```
#
# SRA Accessed: `2020/12/31`
#
# Results: `184 729`
#
#
# ### Eukarya
#
# - File: `euk_SraRunInfo.csv`
#
# Search Term:
# ```
# ("Eukaryota"[Organism] NOT "Metazoa"[Organism]) AND ("type_rnaseq"[Filter] OR "metagenomic"[Filter] OR "metatranscriptomic"[Filter]) AND cluster_public[prop] AND "platform illumina"[Properties]
# ```
#
# SRA Accessed: `2021/01/01`
#
# Results: `367 924`
#
#
# ### Prokaya / Other
#
# - File: `pro_SraRunInfo.csv`
#
# Search Term:
# ```
# ("type_rnaseq"[Filter] OR "metagenomic"[Filter] OR "metatranscriptomic"[Filter]) NOT "Eukaryota"[Organism] AND cluster_public[prop] AND "platform illumina"[Properties]
# ```
#
# SRA Accessed: `2020/12/31`
#
# Results: `2 079 185`
#
# ### Virome
#
# - File: `viro_SraRunInfo.csv`
#
# Search Term:
# ```
# "VIRAL METAGENOME" OR "VIROME" OR "VIROMIC" OR "VIRAL RNA" OR "VIRAL METAGENOMICS" NOT amplicon[All Fields] AND "platform illumina"[Properties] AND cluster_public[prop]
# ```
#
# SRA Accessed: `2020/12/31`
#
# Results: `52 072`
#
#
# ### Metagenomic
#
# - File: `meta_SraRunInfo.csv`
#
# Search Term:
# ```
# "METAGENOMIC" NOT amplicon[All Fields] AND "platform illumina"[Properties] AND cluster_public[prop]
# ```
#
# SRA Accessed: `2020/12/31`
#
# Results: `566 826`
#
# ### Bat (with WGS)
#
# - File: `bat_SraRunInfo.csv`
#
# Search Term:
# ```
# "bat" OR txid9397[Organism:exp] AND "platform illumina"[Properties]
# ```
#
# SRA Accessed: `2021/01/01`
#
# Results: `14103`

# %%
# wc / md5 / upload
cd /home/artem/Desktop/serratus/notebook/201230_sra/

wc -l *
md5sum * > SraRunInfo.md5
md5sum *

aws s3 sync ./ s3://serratus-public/notebook/201230_sra/
# Out:
#      14103 bat_SraRunInfo.csv
#     789931 hu_SraRunInfo.csv
#      47763 hu_meta_SraRunInfo.csv
#     184729 inv_SraRunInfo.csv
#     126382 mamm_SraRunInfo.csv
#     566826 meta_SraRunInfo.csv
#    1058559 mu_SraRunInfo.csv
#    2079185 pro_SraRunInfo.csv
#     114078 vert_SraRunInfo.csv
#      52072 viro_SraRunInfo.csv
#    5033628 total
# 4adcf6d54ccad92b0ea718d90656b25b  SraRunInfo.md5
# 41006f8fa8fbe3ce3861a726847c888f  bat_SraRunInfo.csv
# 0e3424b9cbcb2249314dc1ce42fecf0c  hu_SraRunInfo.csv
# ff4f6839d2434c5ecbb0bdc4cbbb990c  hu_meta_SraRunInfo.csv
# 0cdc0f966e6fbdd1a35a63b3260806de  inv_SraRunInfo.csv
# e0ada71c13d1d80776383d7c0120f58c  mamm_SraRunInfo.csv
# 7ffe7e78bc7df55bca73eaac20a026e2  meta_SraRunInfo.csv
# 245884d3ded9056bd278f357347b53bf  mu_SraRunInfo.csv
# 1c2492bfa2cda8d1836dfbf1a22d5e0f  pro_SraRunInfo.csv
# cf36fb9216bc478da656f00b193569aa  vert_SraRunInfo.csv
# 21984f68344cee144268f9fc9ac703e8  viro_SraRunInfo.csv
# upload: ./SraRunInfo.md5 to s3://serratus-public/notebook/201230_sra/SraRunInfo.md5
# upload: ./bat_SraRunInfo.csv to s3://serratus-public/notebook/201230_sra/bat_SraRunInfo.csv
# upload: ./hu_meta_SraRunInfo.csv to s3://serratus-public/notebook/201230_sra/hu_meta_SraRunInfo.csv
# upload: ./mamm_SraRunInfo.csv to s3://serratus-public/notebook/201230_sra/mamm_SraRunInfo.csv
# upload: ./inv_SraRunInfo.csv to s3://serratus-public/notebook/201230_sra/inv_SraRunInfo.csv
# upload: ./vert_SraRunInfo.csv to s3://serratus-public/notebook/201230_sra/vert_SraRunInfo.csv
# upload: ./viro_SraRunInfo.csv to s3://serratus-public/notebook/201230_sra/viro_SraRunInfo.csv
# upload: ./meta_SraRunInfo.csv to s3://serratus-public/notebook/201230_sra/meta_SraRunInfo.csv
# upload: ./hu_SraRunInfo.csv to s3://serratus-public/notebook/201230_sra/hu_SraRunInfo.csv
# upload: ./mu_SraRunInfo.csv to s3://serratus-public/notebook/201230_sra/mu_SraRunInfo.csv
# upload: ./pro_SraRunInfo.csv to s3://serratus-public/notebook/201230_sra/pro_SraRunInfo.csv

# %%
cut -f 1 *

# %% [markdown]
# #  Previous Run Info Files

# %% [markdown]
# ### Human (non-controlled/dbGAP data)
#
# - File: `hu_SraRunInfo.csv`
#
# Search Term:
# ```
# "txid9606"[Organism:exp] AND ("type_rnaseq"[Filter]) AND cluster_public[prop] AND "platform illumina"[Properties]
# ```
# SRA Accessed: `2020/05/30`
#
#
#
# **AND**
#
# - File: `hu_meta_SraRunInfo.csv`
#
# Search Term:
# ```
# "txid9606"[Organism:exp] AND ("metagenomic"[Filter] OR "metatranscriptomic"[Filter]) AND cluster_public[prop] AND "platform illumina"[Properties]
# ```
# SRA Accessed: `2020/05/30`
#
# Results: `36103`
#
#
# ### Mouse
#
# - File: `mu_SraRunInfo.csv`
#
# Search Term:
# ```
# ("Mus musculus"[orgn]) AND ("type_rnaseq"[Filter] OR "metagenomic"[Filter] OR "metatranscriptomic"[Filter]) AND "platform illumina"[Properties]
# ```
#
# SRA Accessed: `2020/06/06`
#
# Results: `890746`
#
# ### Mammalian
#
# - File: `mamm_SraRunInfo.csv`
#
# Search Term:
# ```
# ("Mammalia"[Organism] NOT "Homo sapiens"[Organism] NOT "Mus musculus"[orgn]) AND ("type_rnaseq"[Filter] OR "metagenomic"[Filter] OR "metatranscriptomic"[Filter]) AND "platform illumina"[Properties]
# ```
# SRA Accessed: `2020/06/06`
#
# Results: `100798`
#
# ### Vertebrate
#
# - File: `vert_SraRunInfo.csv`
#
# Search Term:
# ```
# ("Vertebrata"[Organism] NOT "Mammalia"[Organism] NOT "Homo sapiens"[Organism] NOT "Mus musculus"[orgn]) AND ("type_rnaseq"[Filter] OR "metagenomic"[Filter] OR "metatranscriptomic"[Filter]) AND cluster_public[prop] AND "platform illumina"[Properties]
# ```
# SRA Accessed: `2020/05/25`
#
# Results: `94908`
#
# ### Vertebrate2
#
# Vertebrata and Mammalia
# Query: ("Vertebrata"[Organism] NOT "Homo sapiens"[Organism] NOT "Mus musculus"[orgn]) AND ("type_rnaseq"[Filter]) AND cluster_public[prop] AND "platform illumina"[Properties]
#
# Date: 200905 Return: 93981
#
#
# ### Invertebrate
#
# - File: `inv_SraRunInfo.csv`
#
# Search Term:
# ```
# ("type_rnaseq"[Filter] OR "metagenomic"[Filter] OR "metatranscriptomic"[Filter])  NOT "Vertebrata"[Organism] AND cluster_public[prop] AND "platform illumina"[Properties]
# ```
#
# SRA Accessed: `2020/06/12`
#
# Results: `2193740`
#
# ### Bat (update + wgs)
#
# - File: `bat_SraRunInfo.csv`
#
# Search Term:
# ```
# txid9397[Organism:exp] AND "platform illumina"[Properties]
# ```
#
# SRA Accessed: `2020/06/20`
#
# Results: `2823`
#
# ### Virome
#
# - File: `viro_SraRunInfo.csv`
#
# Search Term:
# ```
# "virome" OR "viral metagenome" OR "viral metagenomics" AND cluster_public[prop]
# ```
#
# SRA Accessed: `2020/06/12`
#
# Results: `22251`
#
# ### Virome2
#
# ```
# Virome + Metatranscriptome
# Query: "VIRAL METAGENOME" OR "VIROME" OR "VIROMIC" OR "VIRAL RNA" OR "METATRANSCRIPTOMIC" NOT "METAGENOMIC" NOT amplicon[All Fields] AND "platform illumina"[Properties] AND cluster_public[prop]
# ```
#
# Date: 2000904 Return: 60327
#
# ### Metagenomes
#
# - File: `meta_SraRunInfo.csv`
#
# Search Term:
# ```
# txid256318[Organism:noexp] #"METATRANSCRIPTOMIC"
# ```
#
# SRA Accessed: `2020/07/12`
#
# Results: `163659`
#
# ### Single-Cell RNA-seq
# Note: This is a 'negative' filter, this data-set was not analyzed it is used to separate single-cell RNA-seq from other RNA-seq libraries in downstream analysis.
#
# - File: `scRNA_SraRunInfo.csv`
#
# Search Term:
# ```
# "single-cell" OR "single cell" OR "scRNA-seq" OR "scRNAseq" OR "scRNAseq"
# ```
#
# SRA Accessed: `2020/06/22`
#
# Results: `770828`

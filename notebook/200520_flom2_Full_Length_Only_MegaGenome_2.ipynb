# %% [markdown]
# ## FLOM2: Full Length Only Mega-genome 2
# ```
# Lead     : ababaian / RCE
# Issue    : n/a
# start    : 2020 05 19
# complete : 2020 05 --
# files    : s3://serratus-public/seq/cov3/
# files    : s3://serratus-public/seq/flom2/
# files    : s3://serratus-public/seq/cov3m/
# notebook : s3://serrauts-public/notebook/200519_ab/
# ```
#
# ## Introduction
#
# `ab:`
#
# ```
# Looks like PCV1 and PCV3 are not in the reference data-set [flom1], only PCV2.
# ...
# FLOM1 = 510 Entries via...
# Viruses[Organism] AND srcdb_refseq[PROP] NOT wgs[PROP] NOT cellular organisms[ORGN] NOT AC_000001:AC_999999[PACC] AND ("vhost human"[Filter] AND "vhost vertebrates"[Filter])
# FLOM2 = 2849 Entries vis...
# Viruses[Organism] AND srcdb_refseq[PROP] NOT wgs[PROP] NOT cellular organisms[ORGN] NOT AC_000001:AC_999999[PACC] AND ("vhost human"[Filter] OR "vhost vertebrates"[Filter])
# It's late now, think and discuss tomorrow
# ```
#
# The search term suggested by NCBI defaults misses alot of viruses, we regenerate using all vertebrate and human viruses (humans are not vertebrates to NCBI).
#
# `flom2`, along with `cov2` sequences representing the total pan-genome for coronaviruses will form the basis for `cov3m`.
#
# ## Addendum : 20 05 26 . Human/Pig/Bat/Chicken/Fish sequence mask in FLOM2
#
# `rce:`
#
# >Yes. Blast is done. Converting to bed is trivial, but I'm asking myself how to trust the results. Ideally I'd check them against zoo4 & 5 to see what the effects of the additional masking would be, but I haven't thought of an easy way to do that yet.
# 10:21
# >
# >FYI my strategy was to blast covref3.fa and flom2.fa against human, pig, bat, chicken and fish. I did these separately so we can treat cov differently if needed.
#
# `https://drive5.com/tmp/flom2.vertmask.tz`

# %% [markdown]
# # FLOM2 Input Sequences
# `

# %% [markdown]
# ### FLOM2 Total Search
# `flom2.total.fa` : 2849 Sequences
#
# - Date Accessed: `2020 05 19`
# - [Search Term](https://www.ncbi.nlm.nih.gov/nuccore/?term=Viruses%5BOrganism%5D+AND+srcdb_refseq%5BPROP%5D+NOT+wgs%5BPROP%5D+NOT+cellular+organisms%5BORGN%5D+NOT+AC_000001%3AAC_999999%5BPACC%5D+AND+(%22vhost+human%22%5BFilter%5D+OR+%22vhost+vertebrates%22%5BFilter%5D))
# ```
# Viruses[Organism] AND srcdb_refseq[PROP] NOT  NOT wgs[PROP] NOT cellular organisms[ORGN] NOT AC_000001:AC_999999[PACC] AND ("vhost human"[Filter] OR "vhost vertebrates"[Filter])
# ```
#
# Downloaded to FASTA: `flom2.total.fa`
# Downloaded to GenBank (full): `flom2.total.gb`

# %% [markdown]
# ### FLOM2 - No Coronaviridae taxid:11118 AND No Retroviridae taxid:11632
# `flom2.fa` :
#
# In the `flom1` alignments Retroviruses were highly prone to false-positive hits. For this pass we will remove all retroviruses to prevent lots of false positive 'gunk'.
#
# Coronaviruses are treated seperately as they must be 'merged' with the `cov` pan-genome.
#
# - Search Term:
#
# ```
# Viruses[Organism] NOT "txid11632"[Organism:exp] NOT "txid11118"[Organism:exp] AND srcdb_refseq[PROP] NOT wgs[PROP] NOT cellular organisms[ORGN] NOT AC_000001:AC_999999[PACC] AND ("vhost human"[Filter] OR "vhost vertebrates"[Filter])
# ```

# %% [markdown]
# ### Coronavirus Search taxid:11118
# `flom2.cov.fa` : 64 Sequences
#
# - Search Term:
# ```
# Viruses[Organism] AND "txid11118"[Organism:exp] AND srcdb_refseq[PROP] NOT wgs[PROP] NOT cellular organisms[ORGN] NOT AC_000001:AC_999999[PACC] AND ("vhost human"[Filter] OR "vhost vertebrates"[Filter])
# ```
#
# #### Coronavirus Total Search
# This will be the basis for an updated `cov3.fa`: 37454 sequences
#
# ```
# "txid11118"[Organism:exp]
# ```

# %% [markdown]
# ### Retroviral Search taxid:11632
# `flom2.retro.fa` : 80 Sequences
#
# - Search Term: 80 results
#
# ```
# Viruses[Organism] AND "txid11632"[Organism:exp] AND srcdb_refseq[PROP] NOT wgs[PROP] NOT cellular organisms[ORGN] NOT AC_000001:AC_999999[PACC] AND ("vhost human"[Filter] OR "vhost vertebrates"[Filter])
# ```

# %%
WORK=/home/artem/Desktop/serratus/notebook/200519_ab/
cd $WORK

# Index flom2
samtools faidx flom2.fa

wc -l *
md5sum *
# Out:
#     26293 flom2.cov.fa
#     53716 flom2.cov.gb
#    631345 flom2.fa
#      2705 flom2.fa.fai
#   1479751 flom2.gb
#     10000 flom2.retro.fa
#     24264 flom2.retro.gb
#    667638 flom2.total.fa
#   1557731 flom2.total.gb
#   4453443 total
# a8298eb0c3f1270df36b29bcaec47611  flom2.cov.fa
# 9516f16095ea7893b272a8e7142a49fa  flom2.cov.gb
# ab2a635ab6036a74e5d03772e11f6538  flom2.fa
# 46a11bd1d434f0bf32b8eea4d945f0d2  flom2.fa.fai
# a32333088872791c3c3908ed7f794512  flom2.gb
# 7f06bd7f2d7b22171d8b93a38f045f7b  flom2.retro.fa
# d709be4bf3d2160fe325bda199a56cd0  flom2.retro.gb
# 2f4a66ccf85e43a58c21b2c3dffe7803  flom2.total.fa
# 90de68e6debd400c9e37c5e7ce56b988  flom2.total.gb

# %%
aws s3 sync ./ s3://serratus-public/notebook/200519_ab/
# Out:
# upload: ./flom2.retro.fa to s3://serratus-public/notebook/200519_ab/flom2.retro.fa
# upload: ./flom2.retro.gb to s3://serratus-public/notebook/200519_ab/flom2.retro.gb
# upload: ./flom2.cov.fa to s3://serratus-public/notebook/200519_ab/flom2.cov.fa
# upload: ./flom2.cov.gb to s3://serratus-public/notebook/200519_ab/flom2.cov.gb
# upload: ./flom2.total.fa to s3://serratus-public/notebook/200519_ab/flom2.total.fa
# upload: ./flom2.fa to s3://serratus-public/notebook/200519_ab/flom2.fa
# upload: ./flom2.fa.fai to s3://serratus-public/notebook/200519_ab/flom2.fa.fai
# upload: ./flom2.total.gb to s3://serratus-public/notebook/200519_ab/flom2.total.gb
# upload: ./flom2.gb to s3://serratus-public/notebook/200519_ab/flom2.gb

# %% [markdown]
# # Boot-up / Installation for Genome-Builder

# %%
# EC2 Instance Commands:
# Build/Run `serratus-align`container for indexing
sudo yum install -y docker
sudo yum install -y git
sudo service docker start

#export DOCKERHUB_USER='serratusbio'
#sudo docker login

git clone https://github.com/ababaian/serratus.git; cd serratus/containers
./build_containers

sudo docker run --rm --entrypoint /bin/bash -it serratus-align:latest

# %%
# local bedtools install
wget https://github.com/arq5x/bedtools2/releases/download/v2.29.2/bedtools.static.binary
mv bedtools.static.binary bedtools
chmod 755 bedtools; mv bedtools /usr/bin/

# %%
# Local usearch install
#The clustered database was made with usearch:
wget https://drive5.com/downloads/usearch11.0.667_i86linux32.gz
gzip -dc usearch11.0.667_i86linux32.gz > usearch
chmod 755 usearch; mv usearch /usr/bin/usearch

# %%
# Local Dustmasker install
cd /home/serratus/
wget ftp://ftp.ncbi.nlm.nih.gov/blast/executables/LATEST/ncbi-blast-2.10.0+-x64-linux.tar.gz
tar -xvf ncbi-blast-2.10.0+-x64-linux.tar.gz
cp ncbi-blast-2.10.0+/bin/* /usr/bin/

# %%
# BioPython
pip3 install biopython

# %%
# Install EDirect
# Dependency Hell
yum install -y cpanminus expat-devel
sudo cpanm --force IO::Socket::SSL
sudo cpanm --force LWP::Protocol::https
sudo cpanm --force JSON::PP
sudo cpanm --force HTML::Entities
sudo cpanm --force XML::Simple

perl -MNet::FTP -e \
  '$$ftp = new Net::FTP("ftp.ncbi.nlm.nih.gov", Passive => 1);
  $$ftp->login; $$ftp->binary;
  $$ftp->get("/entrez/entrezdirect/edirect.tar.gz");'
  
tar -xvf edirect.tar.gz; rm edirect.tar.gz
export PATH=${PATH}:/home/serratus/edirect
yes y | ./edirect/setup.sh

# %% [markdown]
# # Mega-Genome Proccesing Steps **UPDATED

# %%
# workdir
mkdir flom2; cd flom2

# Start from flom2
aws s3 cp --recursive s3://serratus-public/notebook/200519_ab/ ./

# Update from RCE
wget https://drive5.com/tmp/flom2.vertmask.tz ./

# %%
# Create a header file to store original flom2 headers
grep "^>" flom2.fa > flom2.headers
gzip flom2.headers

# %%
# Remove duplicates, short sequences and trim headers
#  (retains Accesion)
#  (removes ScientificName)
seqkit rmdup -s -i -D flom2.duplicates flom2.fa |
seqkit seq -i -m 200 - > flom2.tmp
# 0 entries removed

mv flom2.tmp flom2.fa

# %%
## Manually set blacklisted regions
tar -xvf flom2.vertmask.tz

mv flom2.vertmask.bed blacklist.bed

# %%
# SimpleRepeat Mask Annotation
INPUTFA='flom2.fa'
NAME="flom2"

# Short Window Dust Masking ---------------------
# Soft mask low complexity regions via dustmasker
dustmasker -in $INPUTFA \
  -window 30 -outfmt interval \
  -out $NAME.dust30

# Convert interval dust file to bed file
while read -r line; do
  if [ $(echo $line | head -c 1) = ">" ]; then
    header=$( echo $line | sed 's/>//g' - )
  else
    start=$(echo $line | cut -f1 -d' ' -)
    end=$(echo $line | cut -f3 -d' ' - )
    echo -e "$header\t$start\t$end" >> dust30.bed
  fi
done < $NAME.dust30


# Long Window Dust Masking ---------------------
# Soft mask low complexity regions via dustmasker
dustmasker -in $INPUTFA \
  -window 64 -outfmt interval \
  -out $NAME.dust64

# Convert interval dust file to bed file
while read -r line; do
  if [ $(echo $line | head -c 1) = ">" ]; then
    header=$( echo $line | sed 's/>//g' - )
  else
    start=$(echo $line | cut -f1 -d' ' -)
    end=$(echo $line | cut -f3 -d' ' - )
    echo -e "$header\t$start\t$end" >> dust64.bed
  fi
done < $NAME.dust64

echo ''

# %%
# Poly-NT Mask Annotation
INPUTFA='flom2.fa'

# Create polyNT masks (10-X seed)
# FLOM seems to be missing any NT tract >7nt
seqkit locate --bed -i -m 0 -p 'AAAAAAAAAA' $INPUTFA > poly10.bed
  bedtools sort -chrThenSizeA -i poly10.bed > poly10.sort.bed
  bedtools merge -s -i poly10.sort.bed > polyAT.mask.bed

seqkit locate --bed -i -m 0 -p 'GGGGGGGGGG' $INPUTFA > poly10.bed
  bedtools sort -chrThenSizeA -i poly10.bed > poly10.sort.bed
  bedtools merge -s -i poly10.sort.bed > polyGC.mask.bed

cat polyAT.mask.bed polyGC.mask.bed > \
  polyNT.bed

rm polyAT.mask.bed polyGC.mask.bed poly10.bed poly10.sort.bed

# %%
# Combine blacklist, nt mask and dustmask
# Merge the bed files and then sort
cat polyNT.bed blacklist.bed dust30.bed dust64.bed > mask.tmp.bed
  sort -k1,1 -k2,2n mask.tmp.bed > mask.sort.bed
  bedtools merge -i mask.sort.bed > mask.regions.bed
rm mask.sort.bed mask.tmp.bed

wc -l *.bed

rm polyNT.bed blacklist.bed dust30.bed dust64.bed

# %% [markdown]
# ```
#    8924 blacklist.bed
#   39678 dust30.bed
#   45289 dust64.bed
#   45410 mask.regions.bed
#    2182 polyNT.bed
#  141483 total
# ```

# %%
# Hard and Soft Mask the Genome
INPUTFA='flom2.fa'
NAME="flom2"

# Had to manually remove line 8447 which started with "-1"
# There's a bug in there somewhere, likely a 1-base / 0-base

# cov2 pan-genome
# Soft-masked pan-genome
bedtools maskfasta -fi $INPUTFA \
  -bed mask.regions.bed -fo $NAME.softmasked.fa -soft
 
# Hard-masked pan-genome
bedtools maskfasta -fi $INPUTFA \
  -bed mask.regions.bed -fo $NAME.hardmasked.fa

# %%
# Confirm masking worked as expected manually 
diff flom2.fa flom2.softmasked.fa  | head -n20 -
diff flom2.fa flom2.hardmasked.fa  | head -n20 -

# %%
mv flom2.fa flom2.unmasked.fa
mv flom2.hardmasked.fa flom2.fa

# Count each fasta file
wc -l *.fa

# %% [markdown]
# ```
#     26293 flom2.cov.fa
#    732745 flom2.fa
#     10000 flom2.retro.fa
#    732745 flom2.softmasked.fa
#    667638 flom2.total.fa
#    732745 flom2.unmasked.fa
#   2902166 total
# ```

# %%
# Remove intermediates and non deployment files
rm *.dust* *.gb *.fai flom2.cov.* flom2.retro.* flom2.total*

# Compress stuff we don't need immediatly
gzip flom2.softmasked.fa flom2.unmasked.fa mask.regions.bed

# %%
# Build bowtie2 + faidx index for flom2.fa
bowtie2-build --threads 4 --seed 1337 flom2.fa flom2
samtools faidx flom2.fa

md5sum *

# %% [markdown]
# ```
# db745aace20966358caf74e93708d7cc  flom2.1.bt2
# 4785cfeda8f532f74ad43337be6df224  flom2.2.bt2
# 86d2c57c394103649ee33884e50080ff  flom2.3.bt2
# 1ed1b31fbe521fffc2080dba4d840f98  flom2.4.bt2
# 631c8ccb1aa0cb396f04646b979251cb  flom2.fa
# bc92ecb5578ba62831c65355001236da  flom2.fa.fai
# 3185f6f9c7cf7988603daa581e1d8a73  flom2.headers.gz
# bc56f33dc7e9859cf538b74671831453  flom2.rev.1.bt2
# dceacf534ce81e5f345a63131a3c22a3  flom2.rev.2.bt2
# 81faa2af17a6114935e01bc5fac4adbe  flom2.softmasked.fa.gz
# 9ba7efbfe8f65c67a2235f55698bf200  flom2.unmasked.fa.gz
# 23ef223a29ca82d157fcd84069316069  flom2.vertmask.tz
# 3e43c5d067e8c162808332b4f8cc9a2d  mask.regions.bed.gz
# ```

# %%
aws s3 sync ./ s3://serratus-public/seq/flom2/

# %%
################################
# END OF UPDATE ON MAY 26
################################

# %%
# Not Finished !!
# Create sumzer (tsv) file for genome
# 1: accession
# 2: length
# 3: name
# 4: family taxid
mkdir -p tmp; cd tmp

# -----------------------
# Accessionsls
cut -f1 flom2.fa.fai > acc.tmp
# Length
cut -f2 flom2.fa.fai > len.tmp
# Name
gzip -dc flom2.headers.gz \
  | grep -f acc.tmp - \
  | sed 's/>[A-Za-z_0-9\.]*//g' - \
  | sed 's/^ //g' - \
  | sed 's/,.*//g' - \
  > name.tmp
  
# Family (i give up)
# -------------------------
# TA genomeMeta script
# This is not complete.
# Input  : 2704 Accessions
# Returns: 1747 Entries
# looks like a time-out error since only
# first 1747 entries returned, the rest didn't
# break-up into ~1K blocks to run in future
#
cat flom2.fa.fai \
  | python3 genomeMeta.py - \
  > flom2_1.meta.tmp

# NC_030446.1
# NC_024113.1
# NC_003448.1

cat flom2_2.fa.fai \
  | python3 genomeMeta.py - \
  > flom2_2.meta.tmp

cat flom2_1.meta.tmp flom2_2.meta.tmp > flom2.metadata

while IFS= read -r line
do
  RETURN=$(grep "$line" flom2.metadata)
  echo $RETURN >> flom2.sorted.meta
done < acc.tmp

cut -f 5 -d' ' flom2.sorted.meta \
  | sed 's/^$/Unknown/g' - \
  > family.tmp


paste acc.tmp len.tmp name.tmp family.tmp > flom2.sumzer.tsv

# Some entries are stil missing

# %%
# Create sumzer (tsv) file for genome
# + SumZer maker from RCE
# 1: accession
# 2: length
# 3: name
# 4: family taxid
mkdir -p tmp; cd tmp

# Accessions
cut -f1 ../flom2.fa.fai > acc.tmp
# Length
cut -f2 ../flom2.fa.fai > len.tmp

# Fetch all genBank entries for acc.tmp
cat acc.tmp \
  | epost -db nuccore \
  | efetch -format gb \
  > accs.gb

# Fetch all XML entries from ttax
cat acc.tmp \
  | epost -db nuccore \
  | elink -target taxonomy \
  | efetch -mode xml \
  > tax.xml

echo VERSION > strings.txt
echo db_xref >> strings.txt

grep -Ff strings.txt accs.gb \
  | tr -d "\n" \
  | sed "-es/VERSION */@/g" \
  | tr @ "\n" \
  | sed "-es/  * .db_xref=.taxon:/@/g" \
  | sed '-es/"//g' \
  | sed "-es/@/\t/g" \
  > acc_taxid.txt
  

sed "-es/^    <TaxId>\([0-9]*\)<\/TaxId>/@TAXID=\1/" tax.xml \
  | tr -d "\n" \
  | sed "-es/  *//g" \
  | sed "-es/<ScientificName>\([^<]*\)<\/ScientificName><Rank>family<\/Rank>/@FAMILY=\1/g" \
  | tr "@" "\n" \
  | grep "^[TF]" \
  | sed "-es/<.*//" \
  | sed "-es/.*=//" \
  | sed "-es/^\([0-9]*\)$/@\1/" \
  | sed "-es/^\([^0-9].*\)$/\1#/" \
  | tr -d "\n" \
  | tr @ "\n" \
  | sed "-es/#$//g" \
  | tr "#" "\t" \
  | grep -v "^$" \
  > taxid_family.txt

sort -k2 acc_taxid.txt \
  > acc_taxid.sorted.txt

sort -k1 taxid_family.txt \
  > taxid_family.sorted.txt

join -1 2 -2 1 acc_taxid.sorted.txt taxid_family.sorted.txt \
  | sed "-es/ /	/g" \
  | cut -f2,3 \
  > acc_family.txt

# %%
# Not Finished !!
# Create sumzer (tsv) file for genome
# 1: accession
# 2: length
# 3: name
# 4: family taxid
mkdir -p tmp; cd tmp

# Accessions
cut -f1 flom2.fa.fai > acc.tmp
# Length
cut -f2 flom2.fa.fai > len.tmp
# Name
gzip -dc flom2.headers.gz | \
  grep -f acc.tmp - \
  | sed 's/>[A-Za-z_0-9\.]*//g' - \
  | sed 's/^ //g' - \
  | sed 's/,.*//g' - \
  > name.tmp
  
# Family (i give up)
yes 0 | head -n 2704 > fam.tmp


paste acc.tmp len.tmp name.tmp fam.tmp > flom2.sumzer.tsv

# %%
# Updated summarizer meta-data
aws s3 cp ./flom2.sumzer.tsv s3://serratus-public/seq/flom2/ 
md5sum flom2.sumzer.tsv

# %% [markdown]
# ```
# 36ceed67404740a8bcdcdc6b12822c0e  flom2.sumzer.tsv
# ```

# %%
aws s3 sync ./ s3://serratus-public/seq/flom2/

# %% [markdown]
# ## CovRef3 Alpha Build

# %%
# CoV Fragments and offsets from RCE
# ????
mkdir /home/serratus/cov3a; cd /home/serratus/cov3a

# Download RefSeq (FLOM) Sequences
aws s3 cp s3://serratus-public/seq/flom2/flom2.fa ./
aws s3 cp s3://serratus-public/seq/flom2/flom2.sumzer.tsv ./

# Download CovRef from RCE
aws s3 cp s3://serratus-public/rce/covref/out/covref.fa ./covref3.fa

# %%
# Create a header file to store original flom2 headers
NAME='covref3'

grep "^>" $NAME.fa > $NAME.headers
gzip $NAME.headers

# Remove duplicates, short sequences and trim headers
#  (retains Accesion)
#  (removes ScientificName)
seqkit rmdup -s -i -D $NAME.duplicates $NAME.fa |
seqkit seq -i -m 200 - > $NAME.tmp

# 2476 Duplicate entries are Removed
# there should be no duplicates in covref.fa
# based on the pipeline

mv $NAME.tmp $NAME.fa

# %%
# Manual Blacklisting of bad entries (if they exist)
INPUTFA='covref3.fa'
NAME="covref3"

seqkit grep $INPUTFA -i -r -v \
  -p KC786228 -p AX191447 -p AX191449 \
  -p FB764528 -p HV449436 -p CS382036 \
  -p FV537213 -p AY204705 -p AF209745 \
  -p AY204704 -p FV537211 -p FV537213 \
  > $NAME.bl.fa

# %%
# Manually set blacklisted regions
echo -e "JB181528.1\t3111\t3307" > blacklist.bed
echo -e "CS460762.1\t37177\t37211" >> blacklist.bed
echo -e "CS460762.1\t30166\t30243" >> blacklist.bed
echo -e "CS480537.1\t37170\t37220" >> blacklist.bed
echo -e "CS480537.1\t30166\t30241" >> blacklist.bed
echo -e "MK562374.1\t474\t542" >> blacklist.bed
echo -e "DL231478.1\t43\t2296" >> blacklist.bed
echo -e "KC786228.1\t1\t200 " >> blacklist.bed
echo -e "MK204388.1\t1\t64" >> blacklist.bed
echo -e "JB181528.1\t3675\t4258" >> blacklist.bed
echo -e "CS480537.1\t30130\t30332" >> blacklist.bed
echo -e "DL231478.1\t1\t50" >> blacklist.bed
echo -e "DL231478.1\t8568\t8687" >> blacklist.bed
echo -e "LR721664.1\t31112\t31189" >> blacklist.bed
echo -e "KF530130.1\t4852\t4896" >> blacklist.bed
echo -e "MH002340.1\t30202\t30242" >> blacklist.bed
echo -e "LQ338105.1\t1\t60" >> blacklist.bed
echo -e "KY967725.1\t17220\t17250" >> blacklist.bed
echo -e "DI086074.1\t1\t168" >> blacklist.bed
echo -e "MG600026.1\t3926\t3981" >> blacklist.bed

# %%
# SimpleRepeat Mask Annotation
INPUTFA='covref3.fa'
NAME="covref3"

# Short Window Dust Masking ---------------------
# Soft mask low complexity regions via dustmasker
dustmasker -in $INPUTFA \
  -window 30 -outfmt interval \
  -out $NAME.dust30

# Convert interval dust file to bed file
while read -r line; do
  if [ $(echo $line | head -c 1) = ">" ]; then
    header=$( echo $line | sed 's/>//g' - )
  else
    start=$(echo $line | cut -f1 -d' ' -)
    end=$(echo $line | cut -f3 -d' ' - )
    echo -e "$header\t$start\t$end" >> dust30.bed
  fi
done < $NAME.dust30


# Long Window Dust Masking ---------------------
# Soft mask low complexity regions via dustmasker
dustmasker -in $INPUTFA \
  -window 64 -outfmt interval \
  -out $NAME.dust64

# Convert interval dust file to bed file
while read -r line; do
  if [ $(echo $line | head -c 1) = ">" ]; then
    header=$( echo $line | sed 's/>//g' - )
  else
    start=$(echo $line | cut -f1 -d' ' -)
    end=$(echo $line | cut -f3 -d' ' - )
    echo -e "$header\t$start\t$end" >> dust64.bed
  fi
done < $NAME.dust64

echo ''

# %%
# Poly-NT Mask Annotation
INPUTFA='covref3.fa'

# Create polyNT masks (10-X seed)
# FLOM seems to be missing any NT tract >7nt
seqkit locate --bed -i -m 0 -p 'AAAAAAAAAA' $INPUTFA > poly10.bed
  bedtools sort -chrThenSizeA -i poly10.bed > poly10.sort.bed
  bedtools merge -s -i poly10.sort.bed > polyAT.mask.bed

seqkit locate --bed -i -m 0 -p 'GGGGGGGGGG' $INPUTFA > poly10.bed
  bedtools sort -chrThenSizeA -i poly10.bed > poly10.sort.bed
  bedtools merge -s -i poly10.sort.bed > polyGC.mask.bed

cat polyAT.mask.bed polyGC.mask.bed > \
  polyNT.bed

rm polyAT.mask.bed polyGC.mask.bed poly10.bed poly10.sort.bed

# %%
# Combine blacklist, nt mask and dustmask

# Merge the bed files
cat polyNT.bed blacklist.bed dust30.bed dust64.bed > mask.tmp

# Sort the cat bed file
sort -k1,1 -k2,2n mask.tmp > mask.sort.tmp
  
# Clean up some bugs (-1 and a space)
sed 's/ //g' mask.sort.tmp \
  | sed 's/-1/0/g' - \
  > mask.sort.clean.tmp

# Merge BED file
bedtools merge -i mask.sort.clean.tmp > mask.regions.tmp

# Clean up some bugs (-1 and a space)
sed 's/ //g' mask.regions.tmp \
  | sed 's/-1/0/g' - \
  > mask.regions.bed

rm *tmp

wc -l *.bed

rm polyNT.bed blacklist.bed dust30.bed dust64.bed

# %% [markdown]
# ```
#     20 blacklist.bed
#   2317 dust30.bed
#   3157 dust64.bed
#   3185 mask.regions.bed
#    463 polyNT.bed
#   9142 total
# ```

# %%
# Hard and Soft Mask the Genome
INPUTFA='covref3.bl.fa'
NAME="covref3"

# Had to manually remove line 8447 which started with "-1"
# There's a bug in there somewhere, likely a 1-base / 0-base

# cov2 pan-genome
# Soft-masked pan-genome
bedtools maskfasta -fi $INPUTFA \
  -bed mask.regions.bed -fo $NAME.softmasked.fa -soft
 
# Hard-masked pan-genome
bedtools maskfasta -fi $INPUTFA \
  -bed mask.regions.bed -fo $NAME.hardmasked.fa

# %%
# Confirm masking worked as expected manually 
NAME="covref3"

diff $NAME.fa $NAME.softmasked.fa  | head -n20 -
diff $NAME.fa $NAME.hardmasked.fa  | head -n20 -

cp $NAME.fa $NAME.raw.fa
mv $NAME.hardmasked.fa $NAME.fa
mv $NAME.bl.fa $NAME.unmasked.fa

# Count each fasta file
wc -l *.fa

# %% [markdown]
# ```
#    623900 covref3.fa
#    624904 covref3.raw.fa
#    623900 covref3.softmasked.fa
#    623900 covref3.unmasked.fa
#    732745 flom2.fa
#   3229349 total
# ```

# %%
# Remove intermediates and non deployment files
rm *.dust* *.gb *.fai 

# Compress stuff we don't need immediatly
gzip $NAME.softmasked.fa $NAME.unmasked.fa \
     $NAME.raw.fa mask.regions.bed

# %%
# Build bowtie2 + faidx index for flom2.fa
#bowtie2-build --threads 4 --seed 1337 $NAME.fa $NAME
samtools faidx $NAME.fa

md5sum *

# %%
aws s3 sync ./ s3://serratus-public/seq/covref3/

# %% [markdown]
# ```
# 2e8badc1aab36197d87b151da912bdc6  covref3.duplicates
# e5d5be0b36c7b2ddee2b590b93e2af30  covref3.fa
# 9f2fdf74e29de807375d3dbef2c91450  covref3.fa.fai
# 125c86317e0abbdb2d9c3e8580563b79  covref3.headers.gz
# c1e1b49ad545e49a7270f0fb76534c61  covref3.raw.fa.gz
# 6c8b972c6859645c1a51f8b13dbb2fa0  covref3.softmasked.fa.gz
# 901009678c0e09f708e4472e4a9506f9  covref3.unmasked.fa.gz
# 57f452445b65be1f37ba54ab8dc24bc1  flom2.fa
# 36ceed67404740a8bcdcdc6b12822c0e  flom2.sumzer.tsv
# 0a410ecef1c3b6a25ffcfc7ffb0552f8  mask.regions.bed.gz
# ```

# %%
# Not Finished !!
# Create sumzer (tsv) file for genome
# 1: accession
# 2: length
# 3: name
# 4: family taxid
NAME='covref3'

# Accessions
cut -f1 $NAME.fa.fai > acc.tmp

cut -f1 $NAME.fa.fai \
  | sed 's/:.*//g' - \
  | 
  > acc_2.tmp
  
  split acc_2.tmp
  
# Length
cut -f2 $NAME.fa.fai > len.tmp

# Name
for ACC in $(ls xa*);
do
    gzip -dc $NAME.headers.gz | \
      grep -f $ACC - \
      | sed 's/>[A-Za-z_0-9\.]*//g' - \
      | sed 's/^ //g' - \
      | sed 's/,.*//g' - \
      >> name.tmp
done

rm xa* acc_2.tmp

# Family (i give up)
yes Coronaviridae \
  | head -n $(wc -l acc.tmp | cut -f1 -d' ') \
  > family.tmp

wc -l *tmp

paste acc.tmp len.tmp name.tmp family.tmp > $NAME.sumzer.tsv

md5sum $NAME.sumzer.tsv

rm *tmp

# %%
aws s3 sync ./ s3://serratus-public/seq/covref3/

# %% [markdown]
# ```
# fa35c7027cf4168bff4f816edd5fbee5  covref3.sumzer.tsv
# ```

# %% [markdown]
# ## cov3m Reference Genome

# %%
# CoV Fragments and offsets from RCE
# ????
mkdir -p /home/serratus/cov3a; cd /home/serratus/cov3a

# Download RefSeq (FLOM) Sequences
aws s3 cp s3://serratus-public/seq/flom2/flom2.fa ./
aws s3 cp s3://serratus-public/seq/flom2/flom2.sumzer.tsv ./

# Download CovRef from RCE
aws s3 cp s3://serratus-public/seq/covref3/covref3.fa ./
aws s3 cp s3://serratus-public/seq/covref3/covref3.sumzer.tsv ./

# %%
# Merge covref3 and flom2 for cov3a

cat covref3.fa flom2.fa > cov3a.fa
cat covref3.sumzer.tsv flom2.sumzer.tsv > cov3a.sumzer.tsv

rm covref3* flom2*

# %%
# Build bowtie2 + faidx index
NAME='cov3a'

bowtie2-build --threads 4 --seed 1337 $NAME.fa $NAME
samtools faidx $NAME.fa

md5sum *

# %% [markdown]
# ```
# 6109a2fd984f670e11f3fd59236002f3  cov3a.1.bt2
# 52b1ddef2421c643ecb032895d8ae816  cov3a.2.bt2
# 60896e4a49973f9f822908ee86772a3b  cov3a.3.bt2
# 9dacc07dff34071f891dd0f98cd40ed3  cov3a.4.bt2
# 0eff71abcce35cd479b011bb32ef60ba  cov3a.fa
# d3d06dad9e05957244074c9f92066e39  cov3a.fa.fai
# 2868463d79aefb419d02fa60d7f9dced  cov3a.rev.1.bt2
# c929554a091a5a6579f7c0f5e727ba16  cov3a.rev.2.bt2
# ca56f246a9511c7c895a5d0d4df8ae74  cov3a.sumzer.tsv
# ```

# %%
aws s3 sync ./ s3://serratus-public/seq/cov3a/
